# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('rounds.csv')
df
# Out:
#         Unnamed: 0    eid ename  salary  Unnamed: 4
# 0              0.0  101.0  Amit  2000.0         NaN
# 1              1.0  102.0  Ajay  4000.0         NaN
# 2              NaN    NaN   NaN     NaN         NaN
# 3              NaN    NaN   NaN     NaN         NaN
# 4              NaN    NaN   NaN     NaN         NaN
# ...            ...    ...   ...     ...         ...
# 114944         NaN    NaN   NaN     NaN         NaN
# 114945         NaN    NaN   NaN     NaN         NaN
# 114946         NaN    NaN   NaN     NaN         NaN
# 114947         NaN    NaN   NaN     NaN         NaN
# 114948         NaN    NaN   NaN     NaN         NaN
#
# [114949 rows x 5 columns]

# %%
print((df*2))
# Out:
#         Unnamed: 0    eid     ename  salary  Unnamed: 4
# 0              0.0  202.0  AmitAmit  4000.0         NaN
# 1              2.0  204.0  AjayAjay  8000.0         NaN
# 2              NaN    NaN       NaN     NaN         NaN
# 3              NaN    NaN       NaN     NaN         NaN
# 4              NaN    NaN       NaN     NaN         NaN
# ...            ...    ...       ...     ...         ...
# 114944         NaN    NaN       NaN     NaN         NaN
# 114945         NaN    NaN       NaN     NaN         NaN
# 114946         NaN    NaN       NaN     NaN         NaN
# 114947         NaN    NaN       NaN     NaN         NaN
# 114948         NaN    NaN       NaN     NaN         NaN
#
# [114949 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

eid = [101,102,103]

salary = [13000,15000,18000]

plt.plot(eid, salary)
