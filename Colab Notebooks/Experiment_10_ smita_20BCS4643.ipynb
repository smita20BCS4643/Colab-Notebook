# %% [markdown]
# # smita shinde
# # UID = 20BCS4643
# # class = BIT_B

# %% [markdown]
# Exercise 19 April
#
# ```
# # Regression model of multiple variable
#
# ```

# %%
#importing essential libraries 
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
#reading the data of csv file
df = pd.read_csv('hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
#renaming the column test_score(out of 10) as test_score 
df.rename(columns = {'test_score(out of 10)':'test_score'}, inplace = True)

# %%
df
# Out:
#   experience  test_score  interview_score(out of 10)  salary($)
# 0        NaN         8.0                           9      50000
# 1        NaN         8.0                           6      45000
# 2       five         6.0                           7      60000
# 3        two        10.0                          10      65000
# 4      seven         9.0                           6      70000
# 5      three         7.0                          10      62000
# 6        ten         NaN                           7      72000
# 7     eleven         7.0                           8      80000

# %% [markdown]
# In the cell above you can see some NAN values in the test score column to remove them. We will calculate the median of the test_score column and change the NAN values to the median value of test_score column.

# %%
#here calculating the median of test_score
df.test_score.median()
# Out:
# 8.0

# %%
#filling the NAN values 
df.test_score = df.test_score.fillna(df.test_score.median())
df
# Out:
#   experience  test_score  interview_score(out of 10)  salary($)
# 0        NaN         8.0                           9      50000
# 1        NaN         8.0                           6      45000
# 2       five         6.0                           7      60000
# 3        two        10.0                          10      65000
# 4      seven         9.0                           6      70000
# 5      three         7.0                          10      62000
# 6        ten         8.0                           7      72000
# 7     eleven         7.0                           8      80000

# %% [markdown]
# Now in experience column content some NaN values but given data in column is it in string datatype so we have to replace into integer datatype

# %%
#replacing the experience column values 
df.replace({'experience':{'five':5,'two':2,'seven':7,'three':3,'ten':10,'eleven':11}},inplace=True)
df
# Out:
#    experience  test_score  interview_score(out of 10)  salary($)
# 0         NaN         8.0                           9      50000
# 1         NaN         8.0                           6      45000
# 2         5.0         6.0                           7      60000
# 3         2.0        10.0                          10      65000
# 4         7.0         9.0                           6      70000
# 5         3.0         7.0                          10      62000
# 6        10.0         8.0                           7      72000
# 7        11.0         7.0                           8      80000

# %%
#calculating the median of experience column 
df.experience.median()
# Out:
# 6.0

# %%
#filling the NaN values of experience column by medain value of it.
df.experience = df.experience.fillna(df.experience.median())
df
# Out:
#    experience  test_score  interview_score(out of 10)  salary($)
# 0         6.0         8.0                           9      50000
# 1         6.0         8.0                           6      45000
# 2         5.0         6.0                           7      60000
# 3         2.0        10.0                          10      65000
# 4         7.0         9.0                           6      70000
# 5         3.0         7.0                          10      62000
# 6        10.0         8.0                           7      72000
# 7        11.0         7.0                           8      80000

# %%
# Renaming the salary($) column to salary
df.rename(columns = {'salary($)':'salary'}, inplace = True)

df
# Out:
#    experience  test_score  interview_score(out of 10)  salary
# 0         6.0         8.0                           9   50000
# 1         6.0         8.0                           6   45000
# 2         5.0         6.0                           7   60000
# 3         2.0        10.0                          10   65000
# 4         7.0         9.0                           6   70000
# 5         3.0         7.0                          10   62000
# 6        10.0         8.0                           7   72000
# 7        11.0         7.0                           8   80000

# %%
reg =linear_model.LinearRegression()
#fitting the value of salary to find the regression 
reg.fit(df.drop('salary', axis = 'columns'), df.salary)
# Out:
# LinearRegression()

# %%
#finding and printing the value of coefficient of regression 
reg.coef_
# Out:
# array([2813.00813008, 1333.33333333, 2926.82926829])

# %%
#finding and printing the value of intercept 
reg.intercept_
# Out:
# 11869.91869918695

# %%
#predicting the salary of person who has of 2 yr experienced, 9 test_score and 6 interview_socre
reg.predict([[2,9,6]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([47056.91056911])

# %%
#predicting the salary of person who has of 12 yr experienced, 10 test_score and 10 interview_socre
reg.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([88227.64227642])

# %%
#manually checking the predicted value is accurate or not making use of  Y = MX + B formula

1446.40832732*2+ 620.63279398*9+1755.02421931*6 + 34528.4448108832
# Out:
# 53537.1019272032
