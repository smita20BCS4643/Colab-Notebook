# %%
 # !/usr/bin/python3 
from tkinter import * 
 #creating the application main window. 
top = Tk() 
#Entering the event main loop 
top.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-3396a4675daf> in <module>()
#       2 from tkinter import *
#       3 #creating the application main window.
# ----> 4 top = Tk()
#       5 #Entering the event main loop
#       6 top.mainloop()
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
import tkinter as tk

# %%
pip install tk

# %%
top = Tk()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-8-c85efc388df9> in <module>()
# ----> 1 top = Tk()
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
