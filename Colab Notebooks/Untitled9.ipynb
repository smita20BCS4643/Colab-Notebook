# %%
import tkinter
top =tkinter.Tk()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-17-254284dfe48a> in <module>()
#       1 import tkinter
# ----> 2 top =tkinter.Tk()
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
# !/usr/bin/python3 
from tkinter import * 
parent = Tk() 
name = Label(parent,text = "Name").grid(row = 0, column = 0) 
e1 = Entry(parent).grid(row = 0, column = 1) 
password = Label(parent,text = "Password").grid(row = 1, column = 0) 
e2 = Entry(parent).grid(row = 1, column = 1) 
submit = Button(parent, text = "Submit").grid(row = 4, column = 0) 
parent.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-15-d3f488204d7d> in <module>()
#       1 # !/usr/bin/python3
#       2 from tkinter import *
# ----> 3 parent = Tk()
#       4 name = Label(parent,text = "Name").grid(row = 0, column = 0)
#       5 e1 = Entry(parent).grid(row = 0, column = 1)
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
sudo apt-get install python3-tk
# Out:
#   File "<ipython-input-16-53890485cc8f>", line 1
#     sudo apt-get install python3-tk
#            ^
# SyntaxError: invalid syntax

# %%
top.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fb48ace77c70> in <module>()
# ----> 1 top.mainloop()
#
# NameError: name 'top' is not defined
